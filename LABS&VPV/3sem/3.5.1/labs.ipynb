# %% [markdown]
# .
# .
# .
# .
# .
# part of main program
# .
# .
# .
# .
# .

# %%
# some import

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tkinter as tk
import os
# Out:
# /home/oleg/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
x1 = [0.51,0.76,1,1.25,1.51,1.75,2,2.21,2.54,2.75,3,3.25,3.51,3.76,4,4.32,4.52,4.85]
y1 = [34.23,33.02,32.24,31.77,31.36,30.92,30.38,29.07,27.47,26.60,25.52,24.52,23.75,23.44,23.36,23.23,23.04,22.70]

x2 = [4.85,4.61,4.47,4.30,3.92,3.49,3.11,2.77,2.34,2,1.72,1.32,0.83,0.62,0.44]
y2 = [22.70,22.91,23.03,23.16,23.26,23.75,25.08,26.53,28.39,30.32,30.97,31.62,32.79,33.60,34.79]

plt.figure(figsize=(10,6))
# plt.title('ВАХ системы')
plt.xlabel('I, mA')
plt.ylabel('U, V')
plt.grid()
plt.errorbar(x1, y1, yerr=0.0006, xerr=0.000002, fmt='ob')
plt.errorbar(x2, y2, yerr=0.0006, xerr=0.000002, fmt='or')
# p=np.polyfit(x, y, 1)
# p = [p[0]+0.01, p[1]]
# xx=np.linspace(min(x), max(x), 100)
# yy=np.polyval(p, xx)
# plt.plot(xx, yy, '-r', label=f'k={p[0]:.6f}, b={p[1]:.6f}')
plt.legend()
plt.savefig("./data/data1.png", bbox_inches='tight')
plt.show()
# gl1 = f'k={1/p[0]:.6f}'
# print(gl1)
# print(p)
# print(sum([i**2 for i in y])/sum([i**2 for i in x]))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# data analise

x = [25, 22, 19, 16, 13, 10, 8, 6, 4, 2, 1, 0.50] + [-i for i in [25, 22, 19, 16, 13, 10, 8, 6, 4, 2, 1, 0.50]]
y = [79.80,82,81,78.50,72,60.40,50.20,35.50,18.53,1.90,-7.96,-12.60] + [-99.12,-101.41,-100.61,-97.47,-91.35,-80.20,-69.99,-57.80,-42.30,-24.60,-15.50,-11]
y = [i + 12 for i in y]

plt.figure(figsize=(10,6))
plt.title('ВАХ двойного зонда, I1 = 5V')
plt.xlabel('U, V')
plt.ylabel('I, muA')
plt.grid()
plt.errorbar(x, y, yerr=0.0006, xerr=0.000002, fmt='ob')

p1=np.polyfit(x[1:5], y[1:5], 1)
xx1=np.linspace(min(x[1:5])-20, max(x[1:5])+20, 100)
yy1=np.polyval(p1, xx1)
plt.plot(xx1, yy1, '-r', label=f'k={p1[0]:.6f}, b={p1[1]:.6f}')

p2=np.polyfit(x[1+12:5+12], y[1+12:5+12], 1)
xx2=np.linspace(min(x[1+12:5+12])-20, max(x[1+12:5+12])+20, 100)
yy2=np.polyval(p2, xx2)
plt.plot(xx2, yy2, '-r', label=f'k={p2[0]:.6f}, b={p2[1]:.6f}')

plt.legend()
plt.savefig("./data/data2.png", bbox_inches='tight')
plt.show()

# print(sum([i**2 for i in y])/sum([i**2 for i in x]))

# %%
# data analise

x = [25, 22, 19, 16, 13, 10, 8, 6, 4, 2, 1, 0.50] + [-i for i in [25, 22, 19, 16, 13, 10, 8, 6, 4, 2, 1, 0.50]]
y = [50.91, 49.23, 47.58, 45.70, 42.67, 37.02, 31.10, 23.25, 12.61, 1.57, -4.17, -7] + [-66.60, -64.60, -62.65, -60.50, -57.66, -52.61, -47.54, -40.30, -31, -19.50, -14, -11]
y = [i+9 for i in y]
plt.figure(figsize=(10,6))
plt.title('ВАХ двойного зонда, I1 = 3V')
plt.xlabel('U, V')
plt.ylabel('I, muA')
plt.grid()
plt.errorbar(x, y, yerr=0.0006, xerr=0.000002, fmt='ob')

p1=np.polyfit(x[1:5], y[1:5], 1)
xx1=np.linspace(min(x[1:5])-20, max(x[1:5])+20, 100)
yy1=np.polyval(p1, xx1)
plt.plot(xx1, yy1, '-r', label=f'k={p1[0]:.6f}, b={p1[1]:.6f}')

p2=np.polyfit(x[1+12:5+12], y[1+12:5+12], 1)
xx2=np.linspace(min(x[1+12:5+12])-20, max(x[1+12:5+12])+20, 100)
yy2=np.polyval(p2, xx2)
plt.plot(xx2, yy2, '-r', label=f'k={p2[0]:.6f}, b={p2[1]:.6f}')

plt.legend()
plt.savefig("./data/data3.png", bbox_inches='tight')
plt.show()

# print(sum([i**2 for i in y])/sum([i**2 for i in x]))
# Out:
# 9.571805528647369

# %%
# data analise

x = [25, 22, 19, 16, 13, 10, 8, 6, 4, 2, 1, 0.50] + [-i for i in [25, 22, 19, 16, 13, 10, 8, 6, 4, 2, 1, 0.50]]
y = [24.16, 23.35, 22.59, 21.78, 20.73, 18.51, 15.86, 12.04, 7.31, 0.82, -2.58, -5] + [-35.23, -33.97, -32.73, -31.45, -30.05, -28, -25.80, -22.57, -18.19, -12.30, -8.93, -7.53]
y = [i + 6 for i in y]

plt.figure(figsize=(10,6))
plt.title('ВАХ двойного зонда, I1 = 1.5V')
plt.xlabel('U, V')
plt.ylabel('I, muA')
plt.grid()
plt.errorbar(x, y, yerr=0.0006, xerr=0.000002, fmt='ob')

p1=np.polyfit(x[1:5], y[1:5], 1)
xx1=np.linspace(min(x[1:5])-20, max(x[1:5])+20, 100)
yy1=np.polyval(p1, xx1)
plt.plot(xx1, yy1, '-r', label=f'k={p1[0]:.6f}, b={p1[1]:.6f}')

p2=np.polyfit(x[1+12:5+12], y[1+12:5+12], 1)
xx2=np.linspace(min(x[1+12:5+12])-20, max(x[1+12:5+12])+20, 100)
yy2=np.polyval(p2, xx2)
plt.plot(xx2, yy2, '-r', label=f'k={p2[0]:.6f}, b={p2[1]:.6f}')

plt.legend()
plt.savefig("./data/data4.png", bbox_inches='tight')
plt.show()

print(sum([i**2 for i in y])/sum([i**2 for i in x]))
# Out:
# 2.514398629651506

# %%
x1 = [25, 22, 19, 16, 13, 10, 8, 6, 4, 2, 1, 0.50] + [-i for i in [25, 22, 19, 16, 13, 10, 8, 6, 4, 2, 1, 0.50]]
y1 = [79.80,82,81,78.50,72,60.40,50.20,35.50,18.53,1.90,-7.96,-12.60] + [-99.12,-101.41,-100.61,-97.47,-91.35,-80.20,-69.99,-57.80,-42.30,-24.60,-15.50,-11]

x2 = [25, 22, 19, 16, 13, 10, 8, 6, 4, 2, 1, 0.50] + [-i for i in [25, 22, 19, 16, 13, 10, 8, 6, 4, 2, 1, 0.50]]
y2 = [50.91, 49.23, 47.58, 45.70, 42.67, 37.02, 31.10, 23.25, 12.61, 1.57, -4.17, -7] + [-66.60, -64.60, -62.65, -60.50, -57.66, -52.61, -47.54, -40.30, -31, -19.50, -14, -11]

x3 = [25, 22, 19, 16, 13, 10, 8, 6, 4, 2, 1, 0.50] + [-i for i in [25, 22, 19, 16, 13, 10, 8, 6, 4, 2, 1, 0.50]]
y3 = [24.16, 23.35, 22.59, 21.78, 20.73, 18.51, 15.86, 12.04, 7.31, 0.82, -2.58, -5] + [-35.23, -33.97, -32.73, -31.45, -30.05, -28, -25.80, -22.57, -18.19, -12.30, -8.93, -7.53]

temp = (sum(y1)/len(y1) + sum(y2)/len(y2) + sum(y3)/len(y3))/3

y1 = [i - temp for i in y1]
y2 = [i - temp for i in y2]
y3 = [i - temp for i in y3]

plt.figure(figsize=(10,6))
plt.title('ВАХ системы')
plt.xlabel('I, mA')
plt.ylabel('U, V')
plt.grid()
plt.errorbar(x1, y1, yerr=0.0006, xerr=0.000002, fmt='ob')
plt.errorbar(x2, y2, yerr=0.0006, xerr=0.000002, fmt='or')
plt.errorbar(x3, y3, yerr=0.0006, xerr=0.000002, fmt='og')
# p=np.polyfit(x, y, 1)
# p = [p[0]+0.01, p[1]]
# xx=np.linspace(min(x), max(x), 100)
# yy=np.polyval(p, xx)
# plt.plot(xx, yy, '-r', label=f'k={p[0]:.6f}, b={p[1]:.6f}')
plt.legend()
plt.savefig("./data/data5.png", bbox_inches='tight')
plt.show()
# gl1 = f'k={1/p[0]:.6f}'
# print(gl1)
# print(p)
print(sum([i**2 for i in y])/sum([i**2 for i in x]))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 2.514398629651506

# %% [markdown]
# .
# .
# .
# .
# .
# part of LaTex
# .
# .
# .
# .
# .

# %%
# tables from  exel to LaTex



titles = []

# for column in titles:
#     data = df.to_latex
data = df.to_latex(index=False)
print(data)
# Out:
# \begin{tabular}{rrrr}
# \toprule
# I & U & psi without PI & nu \\
# \midrule
# 265.000000 & 0.620700 & -1.570796 & 1150.000000 \\
# 242.000000 & 0.567900 & -1.481037 & 1460.500000 \\
# 215.000000 & 0.504200 & -1.454441 & 1854.835000 \\
# 186.000000 & 0.433900 & -1.285197 & 2355.640450 \\
# 157.000000 & 0.362500 & -1.196797 & 2991.663371 \\
# 129.000000 & 0.294700 & -1.094797 & 3799.412482 \\
# 105.000000 & 0.233800 & -0.966644 & 4825.253852 \\
# 84.000000 & 0.180900 & -0.822798 & 6128.072392 \\
# 66.800000 & 0.136400 & -0.646798 & 7782.651938 \\
# 0.521700 & 0.099800 & -0.483322 & 9883.967961 \\
# 39.580000 & 0.070100 & 0.000000 & 12552.639310 \\
# 29.320000 & 0.048400 & 0.196350 & 15941.851924 \\
# 20.260000 & 0.033000 & -0.565487 & 20246.151944 \\
# 11.850000 & 0.022400 & -0.942478 & 25712.612968 \\
# 3.700000 & 0.011300 & -1.151917 & 32655.018470 \\
# \bottomrule
# \end{tabular}
