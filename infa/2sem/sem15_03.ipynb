# %% [markdown]
# ребра это пару упорядоченных вершин или неупорядосенные.
# граф это конечная структура .
# граф представляется в виде списка связности, матрица смежности, матрица инцидентности.

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5,6,7,8], [1,4,9,16,25,36,49,64])
plt.show()
