# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %% [markdown]
# data update

# %%
dir = "./configs"
os.system(f'./build/main {dir}/{"1_.json"}')
# Out:
# 0

# %% [markdown]
# look on data

# %%
l = ["phi", "phi_", "psi", "psi_"]
df = pd.read_csv("data/data_phi.csv", sep=";")
df
# Out:
#              t         x
# 0        0.000  1.570000
# 1        0.002  1.569981
# 2        0.004  1.569924
# 3        0.006  1.569830
# 4        0.008  1.569698
# ...        ...       ...
# 99995  199.990  0.393966
# 99996  199.992  0.393966
# 99997  199.994  0.393966
# 99998  199.996  0.393966
# 99999  199.998  0.393966
#
# [100000 rows x 2 columns]

# %% [markdown]
# (почти) фазовый портрет

# %%
df1 = pd.read_csv("data/data_phi.csv", sep=";")[::]
df2 = pd.read_csv("data/data_theta.csv", sep=";")[::]
# fig, axs = plt.subplots(ncols=2)
plt.figure()
plt.title(r"$\theta(\varphi)$")
plt.xlabel(r"$\varphi$")
plt.ylabel(r"$\theta$")
plt.grid()
# plt.axvline(x=df1[' x'][99999], color='red', linestyle="--", label=r'$\varphi_0=$'+f'{df1[' x'][99999]}')
# plt.axhline(y=df2[' x'][99999], color='blue', linestyle="--", label=r'$\theta_0=$'+f'{df2[' x'][99999]%(2*np.pi)}')
# plt.legend()

sns.scatterplot(x=df1[' x'], y=df2[' x'])
# x = np.linspace(0, 10, 10000)
# plt.plot(x,np.sqrt(R**2 - x**2*k/m))
plt.savefig("./output/theta_(phi).png")

# %%
df1 = pd.read_csv("data/data_phi.csv", sep=";")[::]
df2 = pd.read_csv("data/data_phi_.csv", sep=";")[::]
# fig, axs = plt.subplots(ncols=2)
plt.figure()
plt.title(r"$\dot{\varphi}(\varphi)$")
plt.xlabel(r"$\varphi$")
plt.ylabel(r"$\dot{\varphi}$")
plt.grid()
# plt.axvline(x=df1[' x'][99999], color='red', linestyle="--", label=r'$\varphi_0=$'+f'{df1[' x'][99999]%(2*np.pi)}')
# plt.axhline(y=df2[' x'][99999], color='blue', linestyle="--", label=r'$\dot{\varphi}_0=$'+f'{df2[' x'][99999]}')
plt.legend()
sns.scatterplot(x=df1[' x'], y=df2[' x'])
# x = np.linspace(0, 10, 10000)
# plt.plot(x,np.sqrt(R**2 - x**2*k/m))
plt.savefig("./output/phi_(phi).png")
# Out:
# /tmp/ipykernel_17996/3745076340.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df1 = pd.read_csv("data/data_theta.csv", sep=";")[:10000:]
df2 = pd.read_csv("data/data_theta_.csv", sep=";")[:10000:]
# fig, axs = plt.subplots(ncols=2)
plt.figure()
plt.title(r"$\dot{\theta}(\theta)$")
plt.xlabel(r"$\theta$")
plt.ylabel(r"$\dot{\theta}$")
plt.grid()
# plt.axvline(x=df1[' x'][99999], color='red', linestyle="--", label=r'$\theta_0=$'+f'{df1[' x'][99999]%(2*np.pi)}')
# plt.axhline(y=df2[' x'][99999], color='blue', linestyle="--", label=r'$\dot{\theta}_0=$'+f'{df2[' x'][99999]}')
# plt.legend()

sns.scatterplot(x=df1[' x'], y=df2[' x'])
# x = np.linspace(0, 10, 10000)
# plt.plot(x,np.sqrt(R**2 - x**2*k/m))
plt.savefig("./output/theta_(theta).png")

# %% [markdown]
# графики от времени

# %%
df = pd.read_csv("data/data_phi.csv", sep=";")[:200:]
plt.figure()
plt.title(r"$\varphi(t)$")
plt.xlabel(r"$t$")
plt.ylabel(r"$\varphi$")
plt.grid()
# plt.axhline(y=df[' x'][99999], color='blue', linestyle="--", label=r'$\varphi_0=$'+f'{df[' x'][99999]}')
# plt.legend()

sns.scatterplot(data=df, x='t', y=' x')
plt.savefig("./output/phi(t).png")
# print(df[" x"][99999])


#   "phi":3.14159265358968005, for json

# %%
df = pd.read_csv("data/data_phi_.csv", sep=";")[50000::]
plt.figure()
plt.title(r"$\dot{\varphi}(t)$")
plt.xlabel(r"$t$")
plt.ylabel(r"$\dot{\varphi}$")
plt.grid()
plt.axhline(y=df[' x'][99999], color='blue', linestyle="--", label=r'$\dot{\varphi}_0=$'+f'{df[' x'][99999]}')
plt.legend()

sns.scatterplot(data=df, x='t', y=' x')
plt.savefig("./output/phi_(t).png")

# %%
df = pd.read_csv("data/data_theta.csv", sep=";")[:5000:]
plt.figure()
plt.title(r"$\theta(t)$")
plt.xlabel(r"$t$")
plt.ylabel(r"$\theta$")
plt.grid()
# plt.axhline(y=df[' x'][99999], color='blue', linestyle="--", label=r'$\theta_0=$'+f'{df[' x'][99999]%(2*np.pi)}')
plt.legend()

sns.scatterplot(data=df, x='t', y=' x')
plt.savefig("./output/theta(t).png")
# print(f'{df[" x"][99999]%(2*np.pi):.6f}')
# print(f'{df[" x"][99980]%(2*np.pi):.6f}')
# Out:
# /tmp/ipykernel_3006/2352835137.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df = pd.read_csv("data/data_theta_.csv", sep=";")[70000::]
plt.figure()
plt.title(r"$\dot{\theta}(t)$")
plt.xlabel(r"$t$")
plt.ylabel(r"$\dot{\theta}$")
plt.grid()
plt.axhline(y=df[' x'][99999], color='blue', linestyle="--", label=r'$\dot{\theta}_0=$'+f'{df[' x'][99999]%(2*np.pi)}')
plt.legend()

sns.scatterplot(data=df, x='t', y=' x')
plt.savefig("./output/theta_(t).png")

# %%
import json
with open('configs/1.json', 'r') as json_file:
    data = json.load(json_file)


phi = pd.read_csv("data/data_phi.csv", sep=";")[" x"][::]
phi_ = pd.read_csv("data/data_phi_.csv", sep=";")[" x"][::]

theta = pd.read_csv("data/data_theta.csv", sep=";")[" x"][::]
theta_ = pd.read_csv("data/data_theta_.csv", sep=";")[" x"][::]


g = data["params_sys"]["g"]
l = data["params_sys"]["l"]
m = data["params_sys"]["m"]

alpha_1 = data["params_sys"]["alpha_1"]
alpha_2 = data["params_sys"]["alpha_2"]

x_0 = data["params_sys"]["x_0"]
y_0 = data["params_sys"]["y_0"]
z_0 = data["params_sys"]["z_0"]


E = 1/2*m*(l**2)*((theta_**2)*(np.sin(phi)**2) + phi_**2) - m*g*l*np.cos(phi) + alpha_1*alpha_2/np.sqrt(l**2 + x_0**2 + y_0**2 + z_0**2 - 2*l*(x_0*np.sin(phi)*np.cos(theta) + y_0*np.sin(phi)*np.sin(theta) + z_0*np.cos(phi)))
plt.figure()
plt.title("Energy(time)")
plt.grid()
plt.ylabel('Energy')
plt.xlabel('time')
sns.scatterplot(x=pd.read_csv("data/data_phi.csv", sep=";")["t"][::], y=E)

# data = E[::10].to_latex(index=False)
# print(data)
plt.savefig("./output/energy(t).png")

# %%
import json
import os
import tempfile
import subprocess
from concurrent.futures import ThreadPoolExecutor


BASE_CONFIG = {
    "params_model": {
        "algo": "RK4_for_biff",
        "h": 0.001,
        "rep": 500000,
        "skip": 100000,
        "files": {
            "phi": "data_for_biff/data_phi.csv",
            "phi_": "data_for_biff/data_phi_.csv",
            "theta": "data_for_biff/data_theta.csv",
            "theta_": "data_for_biff/data_theta_.csv"
        }
    },
    "params_sys": {
        "g": 9.81,
        "l": 1,
        "m": 1,
        "betta": 0.5,

        "alpha_1": 0.1,
        "alpha_2": 1,
        
        "x_0": 0.0,
        "y_0": 0.1,
        "z_0": 1.1
    },
    "init_cond": {
        "phi": 1.57,
        "phi_": 0,
        "theta": 0,
        "theta_": 5
    }
}




CPP_PROGRAM = "./build/main"
THREADS = 12 

main_list = []



def generate_config(alpha, theta_):
    # config = BASE_CONFIG.copy()
    config = json.loads(json.dumps(BASE_CONFIG))
    config["params_sys"]["alpha_1"] = alpha
    config["init_cond"]["theta_"] = theta_

    with tempfile.NamedTemporaryFile(mode='w', suffix='.json', delete=False) as f:
        json.dump(config, f, indent=4)
        return f.name


def run_cpp_program(config_path):
    """Запускает C++ программу с указанным конфигом"""
    result = subprocess.run(
        [CPP_PROGRAM, config_path],
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True,
        check=True  # Автоматически генерирует исключение при ненулевом коде возврата
    )
    res = list(map(float, result.stdout.split()))
    with open(config_path, 'r') as json_file:
        cc = json.load(json_file)
        main_list.append((res[1], res[3], cc["params_sys"]["alpha_1"], res[2], res[4]))
    try:
        os.unlink(config_path)
        print(f"Временный файл {config_path} удален")
    except OSError as e:
        print(f"Ошибка при удалении {config_path}: {e}")

    return True

def main():
    alphas = [round(x * 0.1, 1) for x in range(-3, 11)]
    thetas_ = [x for x in range(-50,51)]
    configs = [generate_config(alpha, theta_) for theta_ in thetas_ for alpha in alphas]
    
    with ThreadPoolExecutor(max_workers=THREADS) as executor:
        results = list(executor.map(run_cpp_program, configs))
    # for conf in configs:
    #     run_cpp_program(conf[0], conf[1])
    
    print(f"Завершено! Всего запусков: {len(results)}, успешных: {sum(1 for r in results if r == 0)}")

if __name__ == "__main__":
    main()
# Out:
# Временный файл /tmp/tmpwplj469w.json удален
# Временный файл /tmp/tmp2vfuzzek.json удален
# Временный файл /tmp/tmp9zdjf262.json удален
# Временный файл /tmp/tmp0_ks66om.json удален
# Временный файл /tmp/tmpy4h2_zkz.json удален
# Временный файл /tmp/tmpm_wvt_aj.json удален
# Временный файл /tmp/tmpic6h1_qf.json удален
# Временный файл /tmp/tmp349z74yn.json удален
# Временный файл /tmp/tmpk_6gzsxg.json удален
# Временный файл /tmp/tmp87f0c9s5.json удален
# Временный файл /tmp/tmp1_o9kiaa.json удален
# Временный файл /tmp/tmpiujz2c2s.json удален
# Временный файл /tmp/tmphazzhc6_.json удален
# Временный файл /tmp/tmpgz_nus67.json удален
# Временный файл /tmp/tmpdgo4m3rv.json удален
# Временный файл /tmp/tmp6yx926sq.json удален
# Временный файл /tmp/tmpp_ogz4y5.json удален
# Временный файл /tmp/tmpc3f2ny2j.json удален
# Временный файл /tmp/tmpguyxga2p.json удален
# Временный файл /tmp/tmp47p_lbef.json удален
# Временный файл /tmp/tmpvto9wrdd.json удален
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


# Фильтрация данных
filtered_data_ = [
    point for point in main_list
    if not (np.isnan(point[0]) or np.isnan(point[1]) or np.isnan(point[2]))
]
filtered_data = [
    point for point in filtered_data_
    if abs(point[3])+abs(point[4]) < 1e-12
]

# Разделение на координаты
phi = np.array([point[0] for point in filtered_data])
theta = np.array([point[1] for point in filtered_data])
z = np.array([point[2] for point in filtered_data])
x = l*np.sin(phi)*np.cos(theta)
y = l*np.sin(phi)*np.sin(theta)


# Создание 3D графика
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Настройка вида
ax.scatter(x, y, z, c=z, cmap='viridis', s=20, alpha=0.8)
ax.set_xlabel('X Coordinate')
ax.set_ylabel('Y Coordinate')
ax.set_zlabel('Z Coordinate')
ax.set_title('3D Scatter Plot of Filtered Data')

# Настройка угла обзора
ax.view_init(elev=20, azim=45)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.widgets import Slider, Button

# Исходные данные
data = main_list

# Фильтрация данных (удаление NaN значений)
filtered_data = [point for point in data if not (np.isnan(point[0]) or np.isnan(point[1]) or np.isnan(point[2]))]

# Разделение на координаты
x = [point[0] for point in filtered_data]
y = [point[1] for point in filtered_data]
z = [point[2] for point in filtered_data]

# Создание 3D графика
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')

# Настройка визуализации
scatter = ax.scatter(x, y, z, c=z, cmap='viridis', s=40, alpha=0.8, depthshade=True)
ax.set_xlabel('X Coordinate', fontsize=12, labelpad=10)
ax.set_ylabel('Y Coordinate', fontsize=12, labelpad=10)
ax.set_zlabel('Z Coordinate', fontsize=12, labelpad=10)
ax.set_title('Интерактивный 3D график', fontsize=14, pad=20)

# Добавление цветовой шкалы
cbar = fig.colorbar(scatter, ax=ax, pad=0.1)
cbar.set_label('Значение Z', fontsize=10)

# Настройка вида по умолчанию
ax.view_init(elev=30, azim=45)

# Добавление пояснения
plt.figtext(0.5, 0.01, "Используйте левую кнопку мыши для вращения, правую для панорамирования, колесо для масштабирования", 
            ha="center", fontsize=10, bbox={"facecolor":"orange", "alpha":0.2, "pad":5})

# Настройка интерфейса
plt.subplots_adjust(bottom=0.2)

# Добавление элементов управления
ax_elev = plt.axes([0.25, 0.1, 0.65, 0.03])
ax_azim = plt.axes([0.25, 0.05, 0.65, 0.03])

slider_elev = Slider(ax_elev, 'Верт. угол', 0, 90, valinit=30, valstep=1)
slider_azim = Slider(ax_azim, 'Гориз. угол', 0, 360, valinit=45, valstep=1)

def update(val):
    ax.view_init(elev=slider_elev.val, azim=slider_azim.val)
    fig.canvas.draw_idle()

slider_elev.on_changed(update)
slider_azim.on_changed(update)

# Кнопка сброса
resetax = plt.axes([0.8, 0.15, 0.1, 0.04])
button = Button(resetax, 'Сброс', color='lightgoldenrodyellow', hovercolor='0.975')

def reset(event):
    slider_elev.reset()
    slider_azim.reset()
button.on_clicked(reset)

plt.show()
